# %%
from dataset import Dataset
from matplotlib import pyplot as plt

# %%
data = Dataset()

# %%
len(data)
# Out:
# 2511

# %%
lenths = []
for i in range(len(data)):
    lenths.append(len(data[i]))
# Out:
# (1, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (7, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (2, 300)
# (2, 300)
# (1, 300)
# (3, 300)
# (2, 300)
# (2, 300)
# (1, 300)
# (7, 300)
# (1, 300)
# (1, 300)
# (4, 300)
# (4, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (4, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (2, 300)
# (4, 300)
# (2, 300)
# (6, 300)
# (1, 300)
# (4, 300)
# (4, 300)
# (2, 300)
# (1, 300)
# (1, 300)
# (4, 300)
# (14, 300)
# (1, 300)
# (2, 300)
# (2, 300)
# (4, 300)
# (3, 300)
# (2, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (5, 300)
# (1, 300)
# (2, 300)
# (1, 300)
# (1, 300)
# (12, 300)
# (4, 300)
# (5, 300)
# (10, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (5, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (5, 300)
# (5, 300)
# (2, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (5, 300)
# (3, 300)
# (1, 300)
# (6, 300)
# (8, 300)
# (1, 300)
# (2, 300)
# (1, 300)
# (2, 300)
# (1, 300)
# (1, 300)
# (1, 300)
# (5, 300)
# (4, 300)
# (1, 300)
# ...

# %%
plt.hist(lenths, bins = 100)
plt.show()

# %%
lenths = np.array(lenths)

# %%
lenths.mean()
# Out:
# 188.6121067303863

# %%
lenths.max()
# Out:
# 414410

# %%
data[1]
# Out:
# [array([[-0.05419922,  0.01708984, -0.00527954,  0.33203125, -0.25      ,
#          -0.01397705, -0.15039062, -0.265625  ,  0.01647949,  0.3828125 ,
#          -0.03295898, -0.09716797, -0.16308594, -0.04443359,  0.00946045,
#           0.18457031,  0.03637695,  0.16601562,  0.36328125, -0.25585938,
#           0.375     ,  0.171875  ,  0.21386719, -0.19921875,  0.13085938,
#          -0.07275391, -0.02819824,  0.11621094,  0.15332031,  0.09082031,
#           0.06787109, -0.0300293 , -0.16894531, -0.20800781, -0.03710938,
#          -0.22753906,  0.26367188,  0.012146  ,  0.18359375,  0.31054688,
#          -0.10791016, -0.19140625,  0.21582031,  0.13183594, -0.03515625,
#           0.18554688, -0.30859375,  0.04785156, -0.10986328,  0.14355469,
#          -0.43554688, -0.0378418 ,  0.10839844,  0.140625  , -0.10595703,
#           0.26171875, -0.17089844,  0.39453125,  0.12597656, -0.27734375,
#          -0.28125   ,  0.14746094, -0.20996094,  0.02355957,  0.18457031,
# ...

# %%
print(data.get_text(1))
# Out:
# hello
# Hi there! How are you?
# i love mickey mouse.
# I love him. He is my favorite.
# mickey mouse is the absolute best
# I like him too. 😉
# have you ever been to disney world
# No I've not. I want to though.
# where do you go for fun :o
# I go to Disney world every year. What is a male ballerina called?
# have you ever been to disney world
# Now but I would love to go.
# but you go every year?
# Yes I do. it is great. 😃
# tell me about it
# It is fun. How about you?
# whats fun
# I like to dance when I can.

# %%
print(data.enc.decode(data[1], string = True))
# Out:
# hello
# hi there </s> how are you </s>
# i love mickey mouse
# i love him </s> he is my favorite
# mickey mouse is the absolute best
# i like him too </s> </s>
# have you ever been TO disney world
# no i </s> ve not </s> i want TO though
# where do you go for fun </s> o
# i go TO disney world every year </s> what is A male ballerina called </s>
# have you ever been TO disney world
# now but i would love TO go
# but you go every year </s>
# yes i do </s> it is great </s> </s>
# tell me about it
# it is fun </s> how about you </s>
# whats fun
# i like TO dance when i can
